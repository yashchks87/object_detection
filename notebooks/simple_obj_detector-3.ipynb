# %% [markdown]
# # Building your own Object Detector from scratch
#
# This notebook has educational purposes only.
#
# It shows how to build a simple Object Detector from scratch using Tensorflow & Keras.
#
# The model is trained over the Labeled Mask database.
#
# Check this story on medium for more details: https://medium.com/@doleron/building-your-own-object-detector-from-scratch-bfeadfaddad8

# %% [markdown]
# ## Getting the data
#
# Before run this notebook, it is necessary to download the archive file with the training images and respective annotation files.
#
# The file is available on Kaggle: https://www.kaggle.com/datasets/techzizou/labeled-mask-dataset-yolo-darknet
#
# Hit the download button and copy the `archive.zip` to the `data` folder. After that, run the next cell.

# %%
import glob
import os, random
import tensorflow as tf
from tensorflow import keras

# %%
import tensorflow as tf


def tpu_start(device_name):
    device = device_name
    # TPU and GPU mechanism
    if device == "TPU":
        print("Connecting to TPU")
        try:
            # Detects weather system has TPU.
            tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
            print("Running on TPU!", tpu.master())
        except ValueError:
            print("Could not connect to TPU.")
            tpu = None
        if tpu:
            try:
                print("Starting TPU")
                # Connects to the TPU cluster
                tf.config.experimental_connect_to_cluster(tpu)
                # Starts TPU cluster
                tf.tpu.experimental.initialize_tpu_system(tpu)
                # Object gives TPU cluster with 7 replicas
                strategy = tf.distribute.experimental.TPUStrategy(tpu)
                print("TPU started.")
            except:
                print("Failed to start TPU.")
        else:
            device = "GPU"
    # If no TPU then...
    if device != "TPU":
        print("Using single GPU and CPU.")
        strategy = tf.distribute.get_strategy()

    if device == "GPU":
        print(
            f'Number of GPU available: {len(tf.config.experimental.list_physical_devices("GPU"))}'
        )

    AUTO = tf.data.experimental.AUTOTUNE
    REPLICAS = strategy.num_replicas_in_sync
    print(f"Replicas: {REPLICAS}")
    print("Return auto, replica and strategy object in the same order.")
    return AUTO, REPLICAS, strategy

# %%
AUTO, REPLICAS, strategy = tpu_start('GPU')
# Out:
# Using single GPU and CPU.
# Number of GPU available: 1
# Replicas: 1
# Return auto, replica and strategy object in the same order.

# %%
# import pathlib
# import shutil

# data_dir_path = "data/"
# shutil.unpack_archive(data_dir_path + "/archive.zip", data_dir_path)

# data_dir = pathlib.Path(data_dir_path + "/obj/").with_suffix('')

# image_files = list(data_dir.glob('*.jpg'))
# print(len(image_files))

image_files = glob.glob('../../mask_dataset/obj/*.jpg')

# %% [markdown]
# The previous cell uncompress the `archive.zip` file and store the images & text files in the `data/obj` folder. We can inspect the contents of those files as shown below:

# %%
import PIL

# %%
# np.array(PIL.Image.open(image_files[0])).shape

# %%
input_size = 244

def format_image(img, box):
    height, width = img.shape
    max_size = max(height, width)
    r = max_size / input_size
    new_width = int(width / r)
    new_height = int(height / r)
    new_size = (new_width, new_height)
    resized = cv.resize(img, new_size, interpolation= cv.INTER_LINEAR)
    new_image = np.zeros((input_size, input_size), dtype=np.uint8)
    new_image[0:new_height, 0:new_width] = resized

    x, y, w, h = box[0], box[1], box[2], box[3]
    new_box = [int((x - 0.5*w)* width / r), int((y - 0.5*h) * height / r), int(w*width / r), int(h*height / r)]

    return new_image, new_box

# %%
import scipy.io
mat = scipy.io.loadmat('../../IMDB_WIKI/imdb/imdb.mat')

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
sample_img_path = str(image_files[103])
print(sample_img_path)
sample_img = cv.imread(sample_img_path, cv.IMREAD_COLOR)
plt.imshow(cv.cvtColor(sample_img, cv.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# ../../mask_dataset/obj/462-with-mask.jpg

# %% [markdown]
# Basically, the data consist of images files and respective annotation files. Each annotation file has one or more lines in which we can find the class and bounding box coordinates:

# %%
sample_annotation_path = sample_img_path[0:-4] + '.txt'
with open(sample_annotation_path) as f:
    print(f.readlines())
# Out:
# ['0 0.5873015873015873 0.6143410852713178 0.6772486772486772 0.7093023255813954\n']

# %% [markdown]
# The following function filter the files, generating 3 lists:
#
# - training files (70% of images)
# - validation files (20% of images)
# - test files (last 10%)

# %%
files = []
discarded, masked_instance = 0, 0

# %%
def list_files(full_data_path = "data/obj/", image_ext = '.jpg', split_percentage = [70, 20]):


    files = []

    discarded = 0
    masked_instance = 0

    for r, d, f in os.walk(full_data_path):
        for file in f:
            if file.endswith(".txt"):

                # first, let's check if there is only one object
                with open(full_data_path + "/" + file, 'r') as fp:
                    lines = fp.readlines()
                    if len(lines) > 1:
                        discarded += 1
                        continue


                strip = file[0:len(file) - len(".txt")]
                # secondly, check if the paired image actually exist
                image_path = full_data_path + "/" + strip + image_ext
                if os.path.isfile(image_path):
                    # checking the class. '0' means masked, '1' for unmasked
                    if lines[0][0] == '0':
                        masked_instance += 1
                    files.append(strip)

    size = len(files)
    print(str(discarded) + " file(s) discarded")
    print(str(size) + " valid case(s)")
    print(str(masked_instance) + " are masked cases")

    random.shuffle(files)

    split_training = int(split_percentage[0] * size / 100)
    split_validation = split_training + int(split_percentage[1] * size / 100)

    return files[0:split_training], files[split_training:split_validation], files[split_validation:]

# %%
training_files, validation_files, test_files = list_files(full_data_path='../../mask_dataset/obj/')

print(str(len(training_files)) + " training files")
print(str(len(validation_files)) + " validation files")
print(str(len(test_files)) + " test files")
# Out:
# 218 file(s) discarded
# 1292 valid case(s)
# 832 are masked cases
# 904 training files
# 258 validation files
# 130 test files

# %% [markdown]
# This is actually a small dataset. We have only 904 images to train our model!
#
# Let's combine image and annotations in order to check if we actually understand how to deal with the data.
#
# In addition, let's format the images for the input size of our model (244 x 244)

# %%
input_size = 244

def format_image(img, box):
    height, width = img.shape
    max_size = max(height, width)
    r = max_size / input_size
    new_width = int(width / r)
    new_height = int(height / r)
    new_size = (new_width, new_height)
    resized = cv.resize(img, new_size, interpolation= cv.INTER_LINEAR)
    new_image = np.zeros((input_size, input_size), dtype=np.uint8)
    new_image[0:new_height, 0:new_width] = resized

    x, y, w, h = box[0], box[1], box[2], box[3]
    new_box = [int((x - 0.5*w)* width / r), int((y - 0.5*h) * height / r), int(w*width / r), int(h*height / r)]

    return new_image, new_box

# %%
temp_img = cv.imread("../../mask_dataset/obj/5-with-mask.jpg", cv.IMREAD_GRAYSCALE)

temp_box = [0.38183279742765275, 0.6171428571428571, 0.43569131832797425, 0.6285714285714286]

temp_img_formated, box = format_image(temp_img, temp_box)

temp_color_img = cv.cvtColor(temp_img_formated, cv.COLOR_GRAY2RGB)

cv.rectangle(temp_color_img, box, (0, 255, 0), 2)

plt.imshow(temp_color_img)
plt.axis("off")
plt.show()

# %%
temp_img = cv.imread("../../mask_dataset/obj/149.jpg", cv.IMREAD_GRAYSCALE)
temp_box = [0.5171875, 0.5911214953271028, 0.621875, 0.6495327102803738]

temp_img_formated, box = format_image(temp_img, temp_box)

temp_color_img = cv.cvtColor(temp_img_formated, cv.COLOR_GRAY2RGB)

cv.rectangle(temp_color_img, box, (0, 0, 255), 2)

plt.imshow(temp_color_img)
plt.axis("off")
plt.show()

# %% [markdown]
# The dataset is composed by different images of peoplse using or not masks. Let's create a tensorflow dataset with the images:

# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # disabling verbose tf logging

# uncomment the following line if you want to force CPU
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.2

# %%
def data_load(files, full_data_path = "data/obj/", image_ext = ".jpg"):
    X = []
    Y = []

    for file in files:
        img = cv.imread(os.path.join(full_data_path, file + image_ext), cv.IMREAD_GRAYSCALE)

        k = 1

        with open(full_data_path + "/" + file + ".txt", 'r') as fp:
            line = fp.readlines()[0]
            if line[0] == '0':
                k = 0

            box = np.array(line[1:].split(), dtype=float)

        img, box = format_image(img, box)
        img = img.astype(float) / 255.
        box = np.asarray(box, dtype=float) / input_size
        label = np.append(box, k)

        X.append(img)
        Y.append(label)

    X = np.array(X)

    X = np.expand_dims(X, axis=3)

    X = tf.convert_to_tensor(X, dtype=tf.float32)

    Y = tf.convert_to_tensor(Y, dtype=tf.float32)

    result = tf.data.Dataset.from_tensor_slices((X, Y))

    return result

# %%
raw_train_ds = data_load(training_files, full_data_path='../../mask_dataset/obj/')

# %%
raw_validation_ds = data_load(validation_files, full_data_path='../../mask_dataset/obj/')

# %%
raw_test_ds = data_load(test_files, full_data_path='../../mask_dataset/obj/')

# %% [markdown]
# The training, validation & test datasets must be set up in order to follow the tensorflow guideline (https://www.tensorflow.org/datasets/performances):

# %%
CLASSES = 2

def format_instance(image, label):
    return image, (tf.one_hot(int(label[4]), CLASSES), [label[0], label[1], label[2], label[3]])

# %%
BATCH_SIZE = 32

# see https://www.tensorflow.org/guide/data_performance

def tune_training_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(1024, reshuffle_each_iteration=True)
    dataset = dataset.repeat() # The dataset be repeated indefinitely.
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
train_ds = tune_training_ds(raw_train_ds)

# %%
def tune_validation_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(len(validation_files) // 4)
    # dataset = dataset.repeat()
    return dataset

# %%
validation_ds = tune_validation_ds(raw_validation_ds)

# %% [markdown]
# Let's inspect our training dataset:

# %%
plt.figure(figsize=(20, 10))
for images, labels in train_ds.take(1):
    for i in range(BATCH_SIZE):
        ax = plt.subplot(4, BATCH_SIZE//4, i + 1)
        label = labels[0][i]
        box = (labels[1][i] * input_size)
        box = tf.cast(box, tf.int32)

        image = images[i].numpy().astype("float") * 255.0
        image = image.astype(np.uint8)
        image_color = cv.cvtColor(image, cv.COLOR_GRAY2RGB)

        color = (0, 0, 255)
        if label[0] > 0:
            color = (0, 255, 0)

        cv.rectangle(image_color, box.numpy(), color, 2)

        plt.imshow(image_color)
        plt.axis("off")

# %% [markdown]
# Based on the image above, we can realize that the training dataset is correctly set. Blue rectangles represent bounding box of **unmask people**. A green rectangle represent a masked person.
#
# Once the data is ready, we can start our modelling and training.

# %% [markdown]
# ## The model
#
# Since we are building a object detector, our model have two heads: one to classify the object type (or label or class) and other head to output the object bounding box. In order to achieve that, we use Tensorflow Funcional API, as follows:

# %%
DROPOUT_FACTOR = 0.5

def build_feature_extractor(inputs):

    x = tf.keras.layers.Conv2D(16, kernel_size=3, activation='relu', input_shape=(input_size, input_size, 1))(inputs)
    x = tf.keras.layers.AveragePooling2D(2,2)(x)

    x = tf.keras.layers.Conv2D(32, kernel_size=3, activation = 'relu')(x)
    x = tf.keras.layers.AveragePooling2D(2,2)(x)

    x = tf.keras.layers.Conv2D(64, kernel_size=3, activation = 'relu')(x)
    x = tf.keras.layers.Dropout(DROPOUT_FACTOR)(x)
    x = tf.keras.layers.AveragePooling2D(2,2)(x)

    return x

def build_model_adaptor(inputs):
  x = tf.keras.layers.Flatten()(inputs)
  x = tf.keras.layers.Dense(64, activation='relu')(x)
  return x

def build_classifier_head(inputs):
  return tf.keras.layers.Dense(CLASSES, activation='softmax', name = 'classifier_head')(inputs)

def build_regressor_head(inputs):
    return tf.keras.layers.Dense(units = '4', name = 'regressor_head')(inputs)

def build_model(inputs):

    feature_extractor = build_feature_extractor(inputs)

    model_adaptor = build_model_adaptor(feature_extractor)

    classification_head = build_classifier_head(model_adaptor)

    regressor_head = build_regressor_head(model_adaptor)

    model = tf.keras.Model(inputs = inputs, outputs = [classification_head, regressor_head])

    model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss = {'classifier_head' : 'categorical_crossentropy', 'regressor_head' : 'mse' },
              metrics = {'classifier_head' : 'accuracy', 'regressor_head' : 'mse' })

    return model

# %% [markdown]
# It is notewhortly that each network head has a specific set of loss function and metrics:

# %%
with strategy.scope():
    model = build_model(tf.keras.layers.Input(shape=(input_size, input_size, 1,)))

    model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 244, 244, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 242, 242, 16  160         ['input_1[0][0]']
#                                 )
#
#  average_pooling2d (AveragePool  (None, 121, 121, 16  0          ['conv2d[0][0]']
#  ing2D)                         )
#
#  conv2d_1 (Conv2D)              (None, 119, 119, 32  4640        ['average_pooling2d[0][0]']
#                                 )
#
#  average_pooling2d_1 (AveragePo  (None, 59, 59, 32)  0           ['conv2d_1[0][0]']
#  oling2D)
#
#  conv2d_2 (Conv2D)              (None, 57, 57, 64)   18496       ['average_pooling2d_1[0][0]']
#
#  dropout (Dropout)              (None, 57, 57, 64)   0           ['conv2d_2[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 28, 28, 64)  0           ['dropout[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 50176)        0           ['average_pooling2d_2[0][0]']
#
#  dense (Dense)                  (None, 64)           3211328     ['flatten[0][0]']
#
#  classifier_head (Dense)        (None, 2)            130         ['dense[0][0]']
#
#  regressor_head (Dense)         (None, 4)            260         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 3,235,014
# Trainable params: 3,235,014
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Since we have few data, we must keep the model small. The model can be vizualized below:

# %%
# plot_model requires graphviz & pydot
# see https://github.com/XifengGuo/CapsNet-Keras/issues/7#issuecomment-370745440
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ## Model training
#
# Our model is all set and we can start the training, as shown in the next cell:

# %%
with strategy.scope():
    EPOCHS = 100

    history = model.fit(train_ds,
                        steps_per_epoch=(len(training_files) // BATCH_SIZE),
                        validation_data=validation_ds, validation_steps=1,
                        epochs=EPOCHS,
                        verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0424 - classifier_head_loss: 0.0315 - regressor_head_loss: 0.0109 - classifier_head_accuracy: 0.9900 - regressor_head_mse: 0.0109 - val_loss: 0.4611 - val_classifier_head_loss: 0.4351 - val_regressor_head_loss: 0.0260 - val_classifier_head_accuracy: 0.9219 - val_regressor_head_mse: 0.0260
# Epoch 2/100
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0524 - classifier_head_loss: 0.0415 - regressor_head_loss: 0.0110 - classifier_head_accuracy: 0.9888 - regressor_head_mse: 0.0110 - val_loss: 0.6691 - val_classifier_head_loss: 0.6437 - val_regressor_head_loss: 0.0254 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0254
# Epoch 3/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0380 - classifier_head_loss: 0.0282 - regressor_head_loss: 0.0098 - classifier_head_accuracy: 0.9922 - regressor_head_mse: 0.0098 - val_loss: 0.4337 - val_classifier_head_loss: 0.4113 - val_regressor_head_loss: 0.0224 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0224
# Epoch 4/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0476 - classifier_head_loss: 0.0360 - regressor_head_loss: 0.0116 - classifier_head_accuracy: 0.9844 - regressor_head_mse: 0.0116 - val_loss: 0.5153 - val_classifier_head_loss: 0.4936 - val_regressor_head_loss: 0.0217 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0217
# Epoch 5/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0356 - classifier_head_loss: 0.0252 - regressor_head_loss: 0.0103 - classifier_head_accuracy: 0.9933 - regressor_head_mse: 0.0103 - val_loss: 0.6229 - val_classifier_head_loss: 0.5992 - val_regressor_head_loss: 0.0236 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0236
# Epoch 6/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0416 - classifier_head_loss: 0.0322 - regressor_head_loss: 0.0094 - classifier_head_accuracy: 0.9922 - regressor_head_mse: 0.0094 - val_loss: 0.4587 - val_classifier_head_loss: 0.4407 - val_regressor_head_loss: 0.0180 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0180
# Epoch 7/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0330 - classifier_head_loss: 0.0233 - regressor_head_loss: 0.0097 - classifier_head_accuracy: 0.9944 - regressor_head_mse: 0.0097 - val_loss: 0.4525 - val_classifier_head_loss: 0.4286 - val_regressor_head_loss: 0.0239 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0239
# Epoch 8/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0249 - classifier_head_loss: 0.0155 - regressor_head_loss: 0.0094 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0094 - val_loss: 0.5816 - val_classifier_head_loss: 0.5534 - val_regressor_head_loss: 0.0282 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0282
# Epoch 9/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0227 - classifier_head_loss: 0.0099 - regressor_head_loss: 0.0128 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0128 - val_loss: 0.4897 - val_classifier_head_loss: 0.4661 - val_regressor_head_loss: 0.0235 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0235
# Epoch 10/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0231 - classifier_head_loss: 0.0123 - regressor_head_loss: 0.0108 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0108 - val_loss: 0.6379 - val_classifier_head_loss: 0.6145 - val_regressor_head_loss: 0.0234 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0234
# Epoch 11/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0296 - classifier_head_loss: 0.0201 - regressor_head_loss: 0.0095 - classifier_head_accuracy: 0.9922 - regressor_head_mse: 0.0095 - val_loss: 0.5117 - val_classifier_head_loss: 0.4900 - val_regressor_head_loss: 0.0217 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0217
# Epoch 12/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0277 - classifier_head_loss: 0.0210 - regressor_head_loss: 0.0068 - classifier_head_accuracy: 0.9933 - regressor_head_mse: 0.0068 - val_loss: 0.4446 - val_classifier_head_loss: 0.4245 - val_regressor_head_loss: 0.0201 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0201
# Epoch 13/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0165 - classifier_head_loss: 0.0106 - regressor_head_loss: 0.0059 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0059 - val_loss: 0.4836 - val_classifier_head_loss: 0.4639 - val_regressor_head_loss: 0.0197 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0197
# Epoch 14/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0207 - classifier_head_loss: 0.0147 - regressor_head_loss: 0.0060 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0060 - val_loss: 0.5748 - val_classifier_head_loss: 0.5481 - val_regressor_head_loss: 0.0267 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0267
# Epoch 15/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0210 - classifier_head_loss: 0.0136 - regressor_head_loss: 0.0074 - classifier_head_accuracy: 0.9955 - regressor_head_mse: 0.0074 - val_loss: 0.8118 - val_classifier_head_loss: 0.7887 - val_regressor_head_loss: 0.0231 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0231
# Epoch 16/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0184 - classifier_head_loss: 0.0124 - regressor_head_loss: 0.0060 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0060 - val_loss: 0.5881 - val_classifier_head_loss: 0.5639 - val_regressor_head_loss: 0.0242 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0242
# Epoch 17/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0237 - classifier_head_loss: 0.0172 - regressor_head_loss: 0.0064 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0064 - val_loss: 0.4821 - val_classifier_head_loss: 0.4652 - val_regressor_head_loss: 0.0169 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0169
# Epoch 18/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0379 - classifier_head_loss: 0.0315 - regressor_head_loss: 0.0064 - classifier_head_accuracy: 0.9900 - regressor_head_mse: 0.0064 - val_loss: 0.7857 - val_classifier_head_loss: 0.7650 - val_regressor_head_loss: 0.0206 - val_classifier_head_accuracy: 0.8125 - val_regressor_head_mse: 0.0206
# Epoch 19/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0332 - classifier_head_loss: 0.0266 - regressor_head_loss: 0.0066 - classifier_head_accuracy: 0.9922 - regressor_head_mse: 0.0066 - val_loss: 0.5603 - val_classifier_head_loss: 0.5411 - val_regressor_head_loss: 0.0193 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0193
# Epoch 20/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0265 - classifier_head_loss: 0.0197 - regressor_head_loss: 0.0068 - classifier_head_accuracy: 0.9944 - regressor_head_mse: 0.0068 - val_loss: 0.4536 - val_classifier_head_loss: 0.4398 - val_regressor_head_loss: 0.0138 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0138
# Epoch 21/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0157 - classifier_head_loss: 0.0106 - regressor_head_loss: 0.0051 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0051 - val_loss: 0.5328 - val_classifier_head_loss: 0.5157 - val_regressor_head_loss: 0.0171 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0171
# Epoch 22/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0237 - classifier_head_loss: 0.0165 - regressor_head_loss: 0.0072 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0072 - val_loss: 0.5424 - val_classifier_head_loss: 0.5250 - val_regressor_head_loss: 0.0175 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0175
# Epoch 23/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0186 - classifier_head_loss: 0.0117 - regressor_head_loss: 0.0069 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0069 - val_loss: 0.7440 - val_classifier_head_loss: 0.7240 - val_regressor_head_loss: 0.0200 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0200
# Epoch 24/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0218 - classifier_head_loss: 0.0155 - regressor_head_loss: 0.0062 - classifier_head_accuracy: 0.9933 - regressor_head_mse: 0.0062 - val_loss: 0.8247 - val_classifier_head_loss: 0.8037 - val_regressor_head_loss: 0.0210 - val_classifier_head_accuracy: 0.7969 - val_regressor_head_mse: 0.0210
# Epoch 25/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0122 - classifier_head_loss: 0.0059 - regressor_head_loss: 0.0063 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0063 - val_loss: 0.6847 - val_classifier_head_loss: 0.6652 - val_regressor_head_loss: 0.0195 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0195
# Epoch 26/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0111 - classifier_head_loss: 0.0055 - regressor_head_loss: 0.0056 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0056 - val_loss: 0.6996 - val_classifier_head_loss: 0.6825 - val_regressor_head_loss: 0.0170 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0170
# Epoch 27/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0127 - classifier_head_loss: 0.0069 - regressor_head_loss: 0.0058 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0058 - val_loss: 0.6111 - val_classifier_head_loss: 0.5922 - val_regressor_head_loss: 0.0189 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0189
# Epoch 28/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0150 - classifier_head_loss: 0.0096 - regressor_head_loss: 0.0055 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0055 - val_loss: 0.5412 - val_classifier_head_loss: 0.5250 - val_regressor_head_loss: 0.0162 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0162
# Epoch 29/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0116 - classifier_head_loss: 0.0057 - regressor_head_loss: 0.0059 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0059 - val_loss: 0.7489 - val_classifier_head_loss: 0.7308 - val_regressor_head_loss: 0.0180 - val_classifier_head_accuracy: 0.8125 - val_regressor_head_mse: 0.0180
# Epoch 30/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0167 - classifier_head_loss: 0.0110 - regressor_head_loss: 0.0057 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0057 - val_loss: 0.8169 - val_classifier_head_loss: 0.7992 - val_regressor_head_loss: 0.0177 - val_classifier_head_accuracy: 0.8281 - val_regressor_head_mse: 0.0177
# Epoch 31/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0135 - classifier_head_loss: 0.0077 - regressor_head_loss: 0.0058 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0058 - val_loss: 0.7530 - val_classifier_head_loss: 0.7345 - val_regressor_head_loss: 0.0185 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0185
# Epoch 32/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0134 - classifier_head_loss: 0.0077 - regressor_head_loss: 0.0056 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0056 - val_loss: 0.6425 - val_classifier_head_loss: 0.6268 - val_regressor_head_loss: 0.0157 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0157
# Epoch 33/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0138 - classifier_head_loss: 0.0092 - regressor_head_loss: 0.0046 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0046 - val_loss: 0.6089 - val_classifier_head_loss: 0.5929 - val_regressor_head_loss: 0.0159 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0159
# Epoch 34/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0105 - classifier_head_loss: 0.0065 - regressor_head_loss: 0.0039 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0039 - val_loss: 0.9619 - val_classifier_head_loss: 0.9439 - val_regressor_head_loss: 0.0181 - val_classifier_head_accuracy: 0.8281 - val_regressor_head_mse: 0.0181
# Epoch 35/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0132 - classifier_head_loss: 0.0091 - regressor_head_loss: 0.0041 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0041 - val_loss: 0.6327 - val_classifier_head_loss: 0.6170 - val_regressor_head_loss: 0.0157 - val_classifier_head_accuracy: 0.8281 - val_regressor_head_mse: 0.0157
# Epoch 36/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0096 - classifier_head_loss: 0.0052 - regressor_head_loss: 0.0044 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0044 - val_loss: 0.7099 - val_classifier_head_loss: 0.6944 - val_regressor_head_loss: 0.0155 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0155
# Epoch 37/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0168 - classifier_head_loss: 0.0120 - regressor_head_loss: 0.0048 - classifier_head_accuracy: 0.9955 - regressor_head_mse: 0.0048 - val_loss: 0.8065 - val_classifier_head_loss: 0.7868 - val_regressor_head_loss: 0.0197 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0197
# Epoch 38/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0197 - classifier_head_loss: 0.0143 - regressor_head_loss: 0.0054 - classifier_head_accuracy: 0.9955 - regressor_head_mse: 0.0054 - val_loss: 0.8153 - val_classifier_head_loss: 0.7984 - val_regressor_head_loss: 0.0169 - val_classifier_head_accuracy: 0.8281 - val_regressor_head_mse: 0.0169
# Epoch 39/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0246 - classifier_head_loss: 0.0182 - regressor_head_loss: 0.0064 - classifier_head_accuracy: 0.9933 - regressor_head_mse: 0.0064 - val_loss: 0.4974 - val_classifier_head_loss: 0.4817 - val_regressor_head_loss: 0.0157 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0157
# Epoch 40/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0095 - classifier_head_loss: 0.0041 - regressor_head_loss: 0.0055 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0055 - val_loss: 0.6457 - val_classifier_head_loss: 0.6283 - val_regressor_head_loss: 0.0174 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0174
# Epoch 41/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0098 - classifier_head_loss: 0.0053 - regressor_head_loss: 0.0045 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0045 - val_loss: 0.6761 - val_classifier_head_loss: 0.6588 - val_regressor_head_loss: 0.0173 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0173
# Epoch 42/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0118 - classifier_head_loss: 0.0064 - regressor_head_loss: 0.0055 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0055 - val_loss: 0.7638 - val_classifier_head_loss: 0.7464 - val_regressor_head_loss: 0.0174 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0174
# Epoch 43/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0183 - classifier_head_loss: 0.0140 - regressor_head_loss: 0.0043 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0043 - val_loss: 0.5611 - val_classifier_head_loss: 0.5466 - val_regressor_head_loss: 0.0145 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0145
# Epoch 44/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0369 - classifier_head_loss: 0.0309 - regressor_head_loss: 0.0060 - classifier_head_accuracy: 0.9922 - regressor_head_mse: 0.0060 - val_loss: 1.3609 - val_classifier_head_loss: 1.3422 - val_regressor_head_loss: 0.0187 - val_classifier_head_accuracy: 0.7656 - val_regressor_head_mse: 0.0187
# Epoch 45/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0351 - classifier_head_loss: 0.0275 - regressor_head_loss: 0.0076 - classifier_head_accuracy: 0.9900 - regressor_head_mse: 0.0076 - val_loss: 0.5454 - val_classifier_head_loss: 0.5282 - val_regressor_head_loss: 0.0172 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0172
# Epoch 46/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0156 - classifier_head_loss: 0.0099 - regressor_head_loss: 0.0056 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0056 - val_loss: 0.7691 - val_classifier_head_loss: 0.7532 - val_regressor_head_loss: 0.0159 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0159
# Epoch 47/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0170 - classifier_head_loss: 0.0123 - regressor_head_loss: 0.0047 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0047 - val_loss: 0.9956 - val_classifier_head_loss: 0.9777 - val_regressor_head_loss: 0.0180 - val_classifier_head_accuracy: 0.8125 - val_regressor_head_mse: 0.0180
# Epoch 48/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0080 - classifier_head_loss: 0.0036 - regressor_head_loss: 0.0044 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0044 - val_loss: 0.5562 - val_classifier_head_loss: 0.5402 - val_regressor_head_loss: 0.0159 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0159
# Epoch 49/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0193 - classifier_head_loss: 0.0149 - regressor_head_loss: 0.0044 - classifier_head_accuracy: 0.9955 - regressor_head_mse: 0.0044 - val_loss: 0.5744 - val_classifier_head_loss: 0.5578 - val_regressor_head_loss: 0.0166 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0166
# Epoch 50/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0271 - classifier_head_loss: 0.0213 - regressor_head_loss: 0.0057 - classifier_head_accuracy: 0.9911 - regressor_head_mse: 0.0057 - val_loss: 0.8895 - val_classifier_head_loss: 0.8724 - val_regressor_head_loss: 0.0171 - val_classifier_head_accuracy: 0.8281 - val_regressor_head_mse: 0.0171
# Epoch 51/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0168 - classifier_head_loss: 0.0124 - regressor_head_loss: 0.0043 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0043 - val_loss: 0.5516 - val_classifier_head_loss: 0.5376 - val_regressor_head_loss: 0.0140 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0140
# Epoch 52/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0097 - classifier_head_loss: 0.0057 - regressor_head_loss: 0.0040 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0040 - val_loss: 0.5912 - val_classifier_head_loss: 0.5756 - val_regressor_head_loss: 0.0156 - val_classifier_head_accuracy: 0.8906 - val_regressor_head_mse: 0.0156
# Epoch 53/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0049 - classifier_head_loss: 0.0015 - regressor_head_loss: 0.0034 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0034 - val_loss: 0.6887 - val_classifier_head_loss: 0.6731 - val_regressor_head_loss: 0.0156 - val_classifier_head_accuracy: 0.9062 - val_regressor_head_mse: 0.0156
# Epoch 54/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0054 - classifier_head_loss: 0.0020 - regressor_head_loss: 0.0034 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0034 - val_loss: 0.8364 - val_classifier_head_loss: 0.8200 - val_regressor_head_loss: 0.0164 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0164
# Epoch 55/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0076 - classifier_head_loss: 0.0038 - regressor_head_loss: 0.0038 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0038 - val_loss: 0.9037 - val_classifier_head_loss: 0.8874 - val_regressor_head_loss: 0.0163 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0163
# Epoch 56/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0087 - classifier_head_loss: 0.0046 - regressor_head_loss: 0.0040 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0040 - val_loss: 1.0309 - val_classifier_head_loss: 1.0152 - val_regressor_head_loss: 0.0156 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0156
# Epoch 57/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0048 - classifier_head_loss: 0.0017 - regressor_head_loss: 0.0031 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0031 - val_loss: 0.6941 - val_classifier_head_loss: 0.6789 - val_regressor_head_loss: 0.0152 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0152
# Epoch 58/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0146 - classifier_head_loss: 0.0112 - regressor_head_loss: 0.0034 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0034 - val_loss: 1.3334 - val_classifier_head_loss: 1.3176 - val_regressor_head_loss: 0.0158 - val_classifier_head_accuracy: 0.7969 - val_regressor_head_mse: 0.0158
# Epoch 59/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0150 - classifier_head_loss: 0.0112 - regressor_head_loss: 0.0039 - classifier_head_accuracy: 0.9967 - regressor_head_mse: 0.0039 - val_loss: 1.3488 - val_classifier_head_loss: 1.3348 - val_regressor_head_loss: 0.0140 - val_classifier_head_accuracy: 0.8125 - val_regressor_head_mse: 0.0140
# Epoch 60/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0099 - classifier_head_loss: 0.0060 - regressor_head_loss: 0.0039 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0039 - val_loss: 0.8766 - val_classifier_head_loss: 0.8610 - val_regressor_head_loss: 0.0156 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0156
# Epoch 61/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0085 - classifier_head_loss: 0.0047 - regressor_head_loss: 0.0038 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0038 - val_loss: 0.7461 - val_classifier_head_loss: 0.7335 - val_regressor_head_loss: 0.0126 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0126
# Epoch 62/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0096 - classifier_head_loss: 0.0058 - regressor_head_loss: 0.0037 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0037 - val_loss: 1.0940 - val_classifier_head_loss: 1.0786 - val_regressor_head_loss: 0.0154 - val_classifier_head_accuracy: 0.8281 - val_regressor_head_mse: 0.0154
# Epoch 63/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0121 - classifier_head_loss: 0.0078 - regressor_head_loss: 0.0044 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0044 - val_loss: 0.8481 - val_classifier_head_loss: 0.8330 - val_regressor_head_loss: 0.0152 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0152
# Epoch 64/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0089 - classifier_head_loss: 0.0046 - regressor_head_loss: 0.0043 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0043 - val_loss: 0.6051 - val_classifier_head_loss: 0.5918 - val_regressor_head_loss: 0.0134 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0134
# Epoch 65/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0082 - classifier_head_loss: 0.0050 - regressor_head_loss: 0.0032 - classifier_head_accuracy: 0.9989 - regressor_head_mse: 0.0032 - val_loss: 0.6991 - val_classifier_head_loss: 0.6859 - val_regressor_head_loss: 0.0132 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0132
# Epoch 66/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0093 - classifier_head_loss: 0.0064 - regressor_head_loss: 0.0030 - classifier_head_accuracy: 0.9978 - regressor_head_mse: 0.0030 - val_loss: 1.0499 - val_classifier_head_loss: 1.0344 - val_regressor_head_loss: 0.0156 - val_classifier_head_accuracy: 0.8125 - val_regressor_head_mse: 0.0156
# Epoch 67/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0043 - classifier_head_loss: 0.0014 - regressor_head_loss: 0.0029 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0029 - val_loss: 0.6272 - val_classifier_head_loss: 0.6145 - val_regressor_head_loss: 0.0128 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0128
# Epoch 68/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0041 - classifier_head_loss: 0.0016 - regressor_head_loss: 0.0026 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0026 - val_loss: 0.7646 - val_classifier_head_loss: 0.7519 - val_regressor_head_loss: 0.0127 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0127
# Epoch 69/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0036 - classifier_head_loss: 0.0010 - regressor_head_loss: 0.0026 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0026 - val_loss: 0.6897 - val_classifier_head_loss: 0.6760 - val_regressor_head_loss: 0.0137 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0137
# Epoch 70/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0031 - classifier_head_loss: 5.5330e-04 - regressor_head_loss: 0.0025 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0025 - val_loss: 0.6805 - val_classifier_head_loss: 0.6670 - val_regressor_head_loss: 0.0135 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0135
# Epoch 71/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0030 - classifier_head_loss: 5.3523e-04 - regressor_head_loss: 0.0024 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0024 - val_loss: 0.6902 - val_classifier_head_loss: 0.6763 - val_regressor_head_loss: 0.0140 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0140
# Epoch 72/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0031 - classifier_head_loss: 4.9842e-04 - regressor_head_loss: 0.0026 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0026 - val_loss: 0.6817 - val_classifier_head_loss: 0.6682 - val_regressor_head_loss: 0.0135 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0135
# Epoch 73/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0027 - classifier_head_loss: 4.7904e-04 - regressor_head_loss: 0.0022 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0022 - val_loss: 0.6836 - val_classifier_head_loss: 0.6708 - val_regressor_head_loss: 0.0128 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0128
# Epoch 74/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0024 - classifier_head_loss: 6.5454e-04 - regressor_head_loss: 0.0018 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0018 - val_loss: 0.6600 - val_classifier_head_loss: 0.6474 - val_regressor_head_loss: 0.0126 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0126
# Epoch 75/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0023 - classifier_head_loss: 4.4183e-04 - regressor_head_loss: 0.0018 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0018 - val_loss: 0.6861 - val_classifier_head_loss: 0.6731 - val_regressor_head_loss: 0.0130 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0130
# Epoch 76/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0023 - classifier_head_loss: 4.6649e-04 - regressor_head_loss: 0.0018 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0018 - val_loss: 0.6929 - val_classifier_head_loss: 0.6794 - val_regressor_head_loss: 0.0135 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0135
# Epoch 77/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0024 - classifier_head_loss: 5.5378e-04 - regressor_head_loss: 0.0019 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0019 - val_loss: 0.6740 - val_classifier_head_loss: 0.6619 - val_regressor_head_loss: 0.0121 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0121
# Epoch 78/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0026 - classifier_head_loss: 6.7799e-04 - regressor_head_loss: 0.0019 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0019 - val_loss: 0.7306 - val_classifier_head_loss: 0.7170 - val_regressor_head_loss: 0.0135 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0135
# Epoch 79/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0026 - classifier_head_loss: 5.1822e-04 - regressor_head_loss: 0.0020 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0020 - val_loss: 0.6804 - val_classifier_head_loss: 0.6675 - val_regressor_head_loss: 0.0129 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0129
# Epoch 80/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0024 - classifier_head_loss: 4.6494e-04 - regressor_head_loss: 0.0019 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0019 - val_loss: 0.6964 - val_classifier_head_loss: 0.6836 - val_regressor_head_loss: 0.0128 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0128
# Epoch 81/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0023 - classifier_head_loss: 2.7976e-04 - regressor_head_loss: 0.0020 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0020 - val_loss: 0.7019 - val_classifier_head_loss: 0.6884 - val_regressor_head_loss: 0.0135 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0135
# Epoch 82/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0024 - classifier_head_loss: 3.4686e-04 - regressor_head_loss: 0.0020 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0020 - val_loss: 0.6766 - val_classifier_head_loss: 0.6640 - val_regressor_head_loss: 0.0126 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0126
# Epoch 83/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0020 - classifier_head_loss: 2.9112e-04 - regressor_head_loss: 0.0017 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0017 - val_loss: 0.6818 - val_classifier_head_loss: 0.6694 - val_regressor_head_loss: 0.0124 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0124
# Epoch 84/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0021 - classifier_head_loss: 4.2561e-04 - regressor_head_loss: 0.0016 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0016 - val_loss: 0.6600 - val_classifier_head_loss: 0.6477 - val_regressor_head_loss: 0.0123 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0123
# Epoch 85/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0020 - classifier_head_loss: 2.8541e-04 - regressor_head_loss: 0.0018 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0018 - val_loss: 0.6687 - val_classifier_head_loss: 0.6566 - val_regressor_head_loss: 0.0121 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0121
# Epoch 86/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0021 - classifier_head_loss: 4.0866e-04 - regressor_head_loss: 0.0016 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0016 - val_loss: 0.6495 - val_classifier_head_loss: 0.6378 - val_regressor_head_loss: 0.0117 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0117
# Epoch 87/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0021 - classifier_head_loss: 3.8037e-04 - regressor_head_loss: 0.0017 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0017 - val_loss: 0.6613 - val_classifier_head_loss: 0.6494 - val_regressor_head_loss: 0.0119 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0119
# Epoch 88/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0019 - classifier_head_loss: 2.5212e-04 - regressor_head_loss: 0.0016 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0016 - val_loss: 0.6715 - val_classifier_head_loss: 0.6594 - val_regressor_head_loss: 0.0120 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0120
# Epoch 89/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0020 - classifier_head_loss: 3.6600e-04 - regressor_head_loss: 0.0017 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0017 - val_loss: 0.6400 - val_classifier_head_loss: 0.6281 - val_regressor_head_loss: 0.0119 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0119
# Epoch 90/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0018 - classifier_head_loss: 3.4093e-04 - regressor_head_loss: 0.0015 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0015 - val_loss: 0.6906 - val_classifier_head_loss: 0.6782 - val_regressor_head_loss: 0.0124 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0124
# Epoch 91/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0019 - classifier_head_loss: 3.7795e-04 - regressor_head_loss: 0.0015 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0015 - val_loss: 0.6552 - val_classifier_head_loss: 0.6432 - val_regressor_head_loss: 0.0120 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0120
# Epoch 92/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0019 - classifier_head_loss: 3.5737e-04 - regressor_head_loss: 0.0016 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0016 - val_loss: 0.6924 - val_classifier_head_loss: 0.6803 - val_regressor_head_loss: 0.0121 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0121
# Epoch 93/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0019 - classifier_head_loss: 3.2865e-04 - regressor_head_loss: 0.0015 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0015 - val_loss: 0.7024 - val_classifier_head_loss: 0.6901 - val_regressor_head_loss: 0.0123 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0123
# Epoch 94/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0018 - classifier_head_loss: 2.6830e-04 - regressor_head_loss: 0.0016 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0016 - val_loss: 0.6470 - val_classifier_head_loss: 0.6350 - val_regressor_head_loss: 0.0120 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0120
# Epoch 95/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0020 - classifier_head_loss: 3.1610e-04 - regressor_head_loss: 0.0017 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0017 - val_loss: 0.6664 - val_classifier_head_loss: 0.6535 - val_regressor_head_loss: 0.0129 - val_classifier_head_accuracy: 0.8438 - val_regressor_head_mse: 0.0129
# Epoch 96/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0019 - classifier_head_loss: 2.5563e-04 - regressor_head_loss: 0.0016 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0016 - val_loss: 0.6564 - val_classifier_head_loss: 0.6443 - val_regressor_head_loss: 0.0121 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0121
# Epoch 97/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0019 - classifier_head_loss: 3.0000e-04 - regressor_head_loss: 0.0016 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0016 - val_loss: 0.6317 - val_classifier_head_loss: 0.6202 - val_regressor_head_loss: 0.0115 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0115
# Epoch 98/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0019 - classifier_head_loss: 4.0133e-04 - regressor_head_loss: 0.0015 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0015 - val_loss: 0.6636 - val_classifier_head_loss: 0.6517 - val_regressor_head_loss: 0.0119 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0119
# Epoch 99/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0019 - classifier_head_loss: 3.7680e-04 - regressor_head_loss: 0.0015 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0015 - val_loss: 0.6583 - val_classifier_head_loss: 0.6463 - val_regressor_head_loss: 0.0120 - val_classifier_head_accuracy: 0.8594 - val_regressor_head_mse: 0.0120
# Epoch 100/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0017 - classifier_head_loss: 3.5230e-04 - regressor_head_loss: 0.0013 - classifier_head_accuracy: 1.0000 - regressor_head_mse: 0.0013 - val_loss: 0.7117 - val_classifier_head_loss: 0.7006 - val_regressor_head_loss: 0.0111 - val_classifier_head_accuracy: 0.8750 - val_regressor_head_mse: 0.0111

# %%
preds = model.predict(validation_ds, verbose=1)
# Out:
# 5/5 [==============================] - 0s 37ms/step

# %%
preds
# Out:
# [array([[6.82348173e-06, 9.99993205e-01],
#         [9.99412179e-01, 5.87860064e-04],
#         [8.52007531e-08, 9.99999881e-01],
#         [1.00000000e+00, 8.07603984e-11],
#         [3.32858950e-01, 6.67141080e-01],
#         [1.00000000e+00, 8.75752193e-10],
#         [1.00000000e+00, 1.32673144e-08],
#         [1.00000000e+00, 2.94538338e-10],
#         [6.23670621e-06, 9.99993801e-01],
#         [2.89006182e-03, 9.97109950e-01],
#         [1.06412843e-01, 8.93587112e-01],
#         [1.00000000e+00, 2.45343901e-09],
#         [1.00000000e+00, 1.81829031e-11],
#         [9.99999881e-01, 1.56254501e-07],
#         [1.00000000e+00, 3.61897198e-15],
#         [4.79903072e-02, 9.52009737e-01],
#         [1.00000000e+00, 1.76971700e-08],
#         [9.99602854e-01, 3.97111813e-04],
#         [1.00000000e+00, 1.77673054e-09],
#         [5.20065606e-01, 4.79934424e-01],
#         [1.63442266e-04, 9.99836564e-01],
#         [9.90421414e-01, 9.57860146e-03],
#         [9.99961138e-01, 3.88265180e-05],
#         [9.99466836e-01, 5.33168612e-04],
#         [3.57371231e-04, 9.99642611e-01],
#         [1.00000000e+00, 9.01387559e-22],
#         [4.26141545e-02, 9.57385838e-01],
#         [9.02432263e-01, 9.75677222e-02],
#         [1.00000000e+00, 9.35846602e-17],
#         [7.99906104e-07, 9.99999166e-01],
#         [2.68586518e-07, 9.99999762e-01],
#         [9.99999404e-01, 6.36405446e-07],
#         [1.81566738e-05, 9.99981880e-01],
#         [2.00949190e-03, 9.97990489e-01],
#         [3.15222949e-01, 6.84777081e-01],
#         [7.55594985e-04, 9.99244452e-01],
#         [2.10704777e-04, 9.99789298e-01],
#         [1.00000000e+00, 1.80756657e-12],
#         [7.34844029e-01, 2.65155971e-01],
#         [3.96681935e-01, 6.03318095e-01],
#         [6.42161369e-01, 3.57838631e-01],
#         [1.00000000e+00, 1.05347588e-12],
#         [9.99018788e-01, 9.81235062e-04],
#         [9.96762514e-01, 3.23741697e-03],
#         [5.97738733e-07, 9.99999404e-01],
#         [3.50990558e-05, 9.99964952e-01],
#         [9.99955773e-01, 4.42676028e-05],
#         [1.03207022e-01, 8.96793008e-01],
#         [3.71277449e-04, 9.99628663e-01],
#         [9.84006584e-01, 1.59934256e-02],
#         [9.99996662e-01, 3.30803437e-06],
#         [9.97920334e-01, 2.07972736e-03],
#         [1.00000000e+00, 4.71630308e-08],
#         [1.07536434e-05, 9.99989271e-01],
#         [7.13082215e-07, 9.99999285e-01],
#         [4.33048233e-04, 9.99566972e-01],
#         [6.04391062e-05, 9.99939561e-01],
#         [1.00000000e+00, 1.60139706e-08],
#         [1.32046500e-03, 9.98679459e-01],
#         [1.00000000e+00, 1.20091270e-09],
#         [1.00000000e+00, 1.19619488e-08],
#         [9.99982238e-01, 1.77497186e-05],
#         [1.04818819e-05, 9.99989510e-01],
#         [9.99992490e-01, 7.49403671e-06],
#         [9.43022847e-01, 5.69771826e-02],
#         [1.00000000e+00, 2.06533748e-12],
#         [4.81596887e-01, 5.18403113e-01],
#         [1.00000000e+00, 9.32289801e-11],
#         [9.98319089e-01, 1.68093946e-03],
#         [9.99987364e-01, 1.26449950e-05],
#         [1.00000000e+00, 4.74833584e-12],
#         [1.00000000e+00, 2.71332379e-08],
#         [1.73210010e-05, 9.99982715e-01],
#         [1.00000000e+00, 5.57145779e-12],
#         [5.59104083e-05, 9.99944091e-01],
#         [9.87104416e-01, 1.28955198e-02],
#         [9.99291420e-01, 7.08599575e-04],
#         [1.00000000e+00, 5.82364781e-11],
#         [9.77168560e-01, 2.28314474e-02],
#         [1.00000000e+00, 4.63926132e-27],
#         [9.99216914e-01, 7.83067488e-04],
#         [1.00000000e+00, 4.10893874e-10],
#         [2.37577874e-03, 9.97624218e-01],
#         [9.99894738e-01, 1.05290434e-04],
#         [1.00000000e+00, 2.99352609e-09],
#         [9.99964833e-01, 3.51085946e-05],
#         [1.49454340e-01, 8.50545704e-01],
#         [1.00000000e+00, 1.03724269e-11],
#         [9.99934077e-01, 6.59384241e-05],
#         [9.99999642e-01, 4.08667574e-07],
#         [2.36360310e-03, 9.97636437e-01],
#         [6.29025044e-06, 9.99993682e-01],
#         [1.00000000e+00, 2.45107690e-09],
#         [4.40047115e-05, 9.99956012e-01],
#         [1.00000000e+00, 1.24875858e-13],
#         [8.96818237e-05, 9.99910355e-01],
#         [9.98088062e-01, 1.91190117e-03],
#         [5.05154487e-04, 9.99494791e-01],
#         [7.47536480e-01, 2.52463460e-01],
#         [9.99999881e-01, 1.48661783e-07],
#         [6.66267715e-06, 9.99993324e-01],
#         [1.00000000e+00, 5.83899335e-12],
#         [5.17667890e-01, 4.82332110e-01],
#         [1.00000000e+00, 1.00879611e-13],
#         [6.69989458e-06, 9.99993324e-01],
#         [3.58376265e-01, 6.41623735e-01],
#         [9.97627676e-01, 2.37235893e-03],
#         [9.99996781e-01, 3.22130290e-06],
#         [5.19133825e-03, 9.94808674e-01],
#         [4.41313721e-02, 9.55868661e-01],
#         [4.60542113e-01, 5.39457917e-01],
#         [1.00000000e+00, 1.31935893e-14],
#         [2.40699667e-03, 9.97592986e-01],
#         [1.00000000e+00, 1.74453030e-09],
#         [4.55043278e-07, 9.99999523e-01],
#         [1.00000000e+00, 7.54899532e-10],
#         [3.42134990e-05, 9.99965787e-01],
#         [6.33278920e-04, 9.99366701e-01],
#         [4.25047074e-05, 9.99957442e-01],
#         [1.00000000e+00, 1.35566736e-09],
#         [1.65554029e-05, 9.99983430e-01],
#         [9.99937773e-01, 6.21828221e-05],
#         [9.99992967e-01, 7.00278270e-06],
#         [9.99922395e-01, 7.76535453e-05],
#         [8.33720151e-06, 9.99991655e-01],
#         [1.00000000e+00, 1.14052372e-10],
#         [6.42161369e-01, 3.57838631e-01],
#         [8.90658915e-01, 1.09341025e-01],
#         [5.34221588e-04, 9.99465764e-01],
#         [3.07394266e-01, 6.92605734e-01],
#         [9.94540513e-01, 5.45946881e-03],
#         [2.47861575e-02, 9.75213826e-01],
#         [7.68061340e-01, 2.31938660e-01],
#         [2.58621364e-03, 9.97413814e-01],
#         [9.99999881e-01, 1.09025187e-07],
#         [9.98313308e-01, 1.68668234e-03],
#         [9.99999404e-01, 5.58055604e-07],
#         [9.99999046e-01, 1.00437535e-06],
#         [9.99998689e-01, 1.29392265e-06],
#         [9.99852777e-01, 1.47153245e-04],
#         [9.99999881e-01, 6.25652845e-08],
#         [9.99989033e-01, 1.09446555e-05],
#         [1.00000000e+00, 2.19464641e-10],
#         [9.83704269e-01, 1.62957665e-02],
#         [9.98144031e-01, 1.85599504e-03],
#         [1.00000000e+00, 8.16428522e-12],
#         [6.84172619e-06, 9.99993205e-01],
#         [9.99659300e-01, 3.40748869e-04],
#         [1.46399867e-02, 9.85359967e-01],
#         [5.70186239e-05, 9.99943018e-01],
#         [1.00000000e+00, 7.09396788e-13],
#         [1.00000000e+00, 1.99261332e-12],
#         [9.99997735e-01, 2.23922507e-06],
#         [9.99999881e-01, 6.01421704e-08],
#         [9.99995947e-01, 4.08674123e-06],
#         [7.87070751e-01, 2.12929189e-01],
#         [9.99994516e-01, 5.44422437e-06],
#         [9.99784648e-01, 2.15318432e-04],
#         [9.48211644e-03, 9.90517914e-01],
#         [1.00000000e+00, 2.68790377e-08],
#         [9.99995112e-01, 4.92303479e-06],
#         [9.90938902e-01, 9.06112883e-03],
#         [6.27366389e-05, 9.99937296e-01],
#         [9.99999404e-01, 6.09441486e-07],
#         [9.76718009e-01, 2.32819729e-02],
#         [9.78154957e-01, 2.18449999e-02],
#         [9.99392629e-01, 6.07399095e-04],
#         [9.98996913e-01, 1.00305746e-03],
#         [4.52288687e-01, 5.47711372e-01],
#         [1.00000000e+00, 6.27487576e-11],
#         [9.99999523e-01, 4.17527787e-07],
#         [1.00000000e+00, 4.95848731e-08],
#         [9.98633206e-01, 1.36680168e-03],
#         [1.00000000e+00, 2.63807861e-15],
#         [9.99676466e-01, 3.23583925e-04],
#         [9.75065768e-01, 2.49342378e-02],
#         [9.99934316e-01, 6.57190321e-05],
#         [3.53988230e-01, 6.46011770e-01],
#         [9.80018914e-01, 1.99810527e-02],
#         [9.98941004e-01, 1.05900771e-03],
#         [5.60384699e-08, 1.00000000e+00],
#         [1.00000000e+00, 6.84674595e-10],
#         [9.33182237e-05, 9.99906659e-01],
#         [2.66039670e-02, 9.73396003e-01],
#         [1.98422073e-04, 9.99801576e-01],
#         [9.99999762e-01, 2.94750862e-07],
#         [2.91668869e-07, 9.99999762e-01],
#         [3.51990014e-01, 6.48009956e-01],
#         [9.99999285e-01, 7.29694591e-07],
#         [9.99991059e-01, 8.98959934e-06],
#         [1.00000000e+00, 8.84059868e-17],
#         [3.32292885e-01, 6.67707145e-01],
#         [9.99972463e-01, 2.75309649e-05],
#         [9.98928010e-01, 1.07195450e-03],
#         [4.13960874e-01, 5.86039066e-01],
#         [9.29625571e-07, 9.99999046e-01],
#         [7.55818188e-03, 9.92441893e-01],
#         [7.97830224e-01, 2.02169776e-01],
#         [9.99998927e-01, 1.11183954e-06],
#         [9.44670737e-01, 5.53292930e-02],
#         [1.00000000e+00, 4.34036140e-09],
#         [1.00000000e+00, 4.71889780e-14],
#         [1.13861847e-06, 9.99998808e-01],
#         [1.00000000e+00, 2.59108707e-12],
#         [9.99998927e-01, 1.08728182e-06],
#         [9.99999762e-01, 2.05057972e-07],
#         [9.99999285e-01, 7.36530069e-07],
#         [1.00000000e+00, 3.41876616e-09],
#         [9.99999881e-01, 6.82475658e-08],
#         [1.86912599e-04, 9.99813139e-01],
#         [4.40047115e-05, 9.99956012e-01],
#         [1.00000000e+00, 3.87078067e-08],
#         [1.00000000e+00, 9.07568118e-12],
#         [2.51549751e-01, 7.48450279e-01],
#         [2.63231620e-03, 9.97367680e-01],
#         [2.10322693e-08, 1.00000000e+00],
#         [2.18206242e-01, 7.81793773e-01],
#         [1.00000000e+00, 4.07044398e-10],
#         [9.98911262e-01, 1.08869444e-03],
#         [9.99869704e-01, 1.30304397e-04],
#         [1.00000000e+00, 5.43594875e-17],
#         [9.99742210e-01, 2.57746986e-04],
#         [9.99020696e-01, 9.79345175e-04],
#         [1.00000000e+00, 1.02125131e-11],
#         [6.00945294e-10, 1.00000000e+00],
#         [1.00000000e+00, 4.08548289e-08],
#         [9.99994755e-01, 5.20307276e-06],
#         [9.99993086e-01, 6.95743802e-06],
#         [1.00000000e+00, 2.08287094e-08],
#         [1.16301571e-07, 9.99999881e-01],
#         [1.00000000e+00, 3.88077695e-11],
#         [1.00000000e+00, 3.75112421e-08],
#         [9.99737799e-01, 2.62191083e-04],
#         [9.99941111e-01, 5.89441624e-05],
#         [9.43988289e-06, 9.99990582e-01],
#         [4.76744361e-07, 9.99999523e-01],
#         [1.00000000e+00, 5.08836600e-08],
#         [1.93846759e-07, 9.99999762e-01],
#         [1.00000000e+00, 3.09514830e-10],
#         [9.99254882e-01, 7.45120284e-04],
#         [5.05983736e-03, 9.94940162e-01],
#         [9.99129951e-01, 8.70121585e-04],
#         [6.84377085e-03, 9.93156254e-01],
#         [9.99444902e-01, 5.55101200e-04],
#         [9.99994755e-01, 5.22361643e-06],
#         [9.99999046e-01, 9.41057408e-07],
#         [9.99982476e-01, 1.75312252e-05],
#         [9.99999166e-01, 8.30982628e-07],
#         [9.56135429e-03, 9.90438640e-01],
#         [1.00000000e+00, 3.36393857e-10],
#         [8.25112693e-06, 9.99991775e-01],
#         [6.05282024e-04, 9.99394655e-01],
#         [3.89977822e-06, 9.99996066e-01],
#         [5.76431241e-08, 1.00000000e+00],
#         [9.99996424e-01, 3.60765921e-06],
#         [1.00000000e+00, 6.08887067e-20],
#         [9.99999881e-01, 1.78106845e-07],
#         [1.00000000e+00, 9.95287325e-11]], dtype=float32),
#  array([[0.12149362, 0.27875417, 0.41844416, 0.39569116],
#         [0.31258127, 0.11070221, 0.38052678, 0.3958651 ],
#         [0.13973895, 0.26244852, 0.45283067, 0.6113755 ],
#         ...,
#         [0.04936854, 0.25957194, 0.56917536, 0.5364706 ],
#         [0.20768717, 0.2876268 , 0.49892247, 0.43333998],
#         [0.21142277, 0.38634276, 0.46711475, 0.40130278]], dtype=float32)]

# %% [markdown]
# The training performance can be checked in the charts below.

# %%
plt.plot(history.history['classifier_head_accuracy'])
plt.plot(history.history['val_classifier_head_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['classifier_head_loss'])
plt.plot(history.history['val_classifier_head_loss'])
plt.title('Classification Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['regressor_head_loss'])
plt.plot(history.history['val_regressor_head_loss'])
plt.title('Bounding Box Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluation
#
# The best way to evaluate the end model performance is by using IoU - intersection over Union - metrics. The following implementation of IoU was adapted from PyImage Search website:

# %%
# adapted from: https://pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/
def intersection_over_union(boxA, boxB):
	xA = max(boxA[0], boxB[0])
	yA = max(boxA[1], boxB[1])
	xB = min(boxA[0] + boxA[2], boxB[0] + boxB[2])
	yB = min(boxA[1] + boxA[3], boxB[1] + boxB[3])
	interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
	boxAArea = (boxA[2] + 1) * (boxA[3] + 1)
	boxBArea = (boxB[2] + 1) * (boxB[3] + 1)
	iou = interArea / float(boxAArea + boxBArea - interArea)
	return iou

# %%
def tune_test_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(1)
    dataset = dataset.repeat()
    return dataset

test_ds = tune_test_ds(raw_test_ds)

# %% [markdown]
# The model performance is finally evaluated on the test dataset. Green boxes indicaates correct classification in which the predicted label (masked-unmasked) matches with the actual label.
# A red box indicate a wrong classification.

# %%
plt.figure(figsize=(20, 10))

test_list = list(test_ds.take(20).as_numpy_iterator())

print(len(test_list))

image, labels = test_list[0]

for i in range(len(test_list)):

    ax = plt.subplot(4, 10, i + 1)
    image, labels = test_list[i]

    predictions = model(image)

    predicted_box = predictions[1][0] * input_size
    predicted_box = tf.cast(predicted_box, tf.int32)

    predicted_label = predictions[0][0]

    image = image[0]

    actual_label = labels[0][0]
    actual_box = labels[1][0] * input_size
    actual_box = tf.cast(actual_box, tf.int32)

    image = image.astype("float") * 255.0
    image = image.astype(np.uint8)
    image_color = cv.cvtColor(image, cv.COLOR_GRAY2RGB)

    color = (255, 0, 0)
    # print box red if predicted and actual label do not match
    if (predicted_label[0] > 0.5 and actual_label[0] > 0) or (predicted_label[0] < 0.5 and actual_label[0] == 0):
        color = (0, 255, 0)

    cv.rectangle(image_color, predicted_box.numpy(), color, 2)
    cv.rectangle(image_color, actual_box.numpy(), (0, 0, 255), 2)

    IoU = intersection_over_union(predicted_box.numpy(), actual_box.numpy())

    plt.title("IoU:" + format(IoU, '.4f'))
    plt.imshow(image_color)
    plt.axis("off")
# Out:
# 20

# %% [markdown]
# ## Conclusion
#
# Taking in consideration the small size of the data used for training and the fact of training the model from scratch without transfer learning, the results above are surprisingly good. We can think in ways to improve it even more:
#
# - The first option to improve the bound box and classificataion performance is increase the training data size which can be easily achieved by data augmentation.
#
# - Tweaking the hyperparameters and finding on way to improve the regularization can either improve the results, reducing the classification and regression errors.
#
# A good enhacement here would be calculating mAP comparing the results to one or more object detectors. Implementing other features like multiscale and multiple detections can also provide a solid understand of real challengings in developing an battle-tested object detector.
